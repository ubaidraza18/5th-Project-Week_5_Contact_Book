# %%
# %%markdown
# #  **Week 5 Project: Contact Book**
# Student Name: M.Ubaid Raza
# This project adds and searches contacts using a dictionary.
# Out:
# #  **Week 5 Project: Contact Book**
# Student Name: M.Ubaid Raza
# This project adds and searches contacts using a dictionary.

# %%
contacts = {
    "Ubaid": {
        "phone": "03001234568",
        "email": "uraza6574@gmail.com"
    }
}

# %%
contacts = {}
print("Contact dictionary is ready.")
# Out:
# Contact dictionary is ready.

# %%
# Empty dictionary for contacts
contacts = {}
print("===== CONTACT BOOK =====")
while True:
    print("\n1. Add Contact")
    print("2. Search Contact")
    print("3. Exit")
    choice = input("Enter your choice: ").strip()
    if choice == "1":
        name = input("Enter contact name: ").strip().title()
        phone = input("Enter phone number: ").strip()
        email = input("Enter email address: ").strip()
        if name == "" or phone == "" or email == "":
            print("All information is required.")
        else:
            contacts[name] = {
                "phone": phone,
                "email": email
            }
            print("Contact added successfully.")
    elif choice == "2":
        search_name = input(
            "Enter contact name to search: "
        ).strip().title()
        if search_name in contacts:
            print("\nContact found!")
            print("Name:", search_name)
            print("Phone:", contacts[search_name]["phone"])
            print("Email:", contacts[search_name]["email"])
        else:
            print("Contact not found.")
    elif choice == "3":
        print("Contact Book closed.")
        break
    else:

        print("Invalid choice. Enter 1, 2, or 3.")
# Out:
# ===== CONTACT BOOK =====
#
# 1. Add Contact
# 2. Search Contact
# 3. Exit
# Enter your choice:  1
# Enter contact name:  Ubaid
# Enter phone number:  03001234568
# Enter email address:  uraza6475@gmail.com
# Contact added successfully.
#
# 1. Add Contact
# 2. Search Contact
# 3. Exit
# Enter your choice:  2
# Enter contact name to search:  Ubaid
# Contact found!
# Name: Ubaid
# Phone: 03001234568
# Email: uraza6475@gmail.com
#
# 1. Add Contact
# 2. Search Contact
# 3. Exit
# Enter your choice:  3
# Contact Book closed.
